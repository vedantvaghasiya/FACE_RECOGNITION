# %%
pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [84 lines of output]
#       C:\Users\Vedant\AppData\Local\Temp\pip-install-qvhqvlsh\dlib_176cf259449f4d968d812b49be47869d\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#         major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
#       C:\Users\Vedant\AppData\Local\Temp\pip-install-qvhqvlsh\dlib_176cf259449f4d968d812b49be47869d\setup.py:235: SyntaxWarning: invalid escape sequence '\('
#         minor = re.findall("set\(CPACK_PACKAGE_VERSION_MINOR.*\"(.*)\"", open(cmake_file).read())[0]
# ...
